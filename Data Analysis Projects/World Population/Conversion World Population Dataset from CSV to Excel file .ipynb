# %%
import pandas as pd
df = pd.read_csv('World-population-by-countries-dataset.csv')
df
# Out:
#                     Country Name Country Code         1960         1961  \
# 0                          Aruba          ABW      54208.0      55434.0
# 1    Africa Eastern and Southern          AFE  130836765.0  134159786.0
# 2                    Afghanistan          AFG    8996967.0    9169406.0
# 3     Africa Western and Central          AFW   96396419.0   98407221.0
# 4                         Angola          AGO    5454938.0    5531451.0
# ..                           ...          ...          ...          ...
# 261                       Kosovo          XKX     947000.0     966000.0
# 262                  Yemen, Rep.          YEM    5315351.0    5393034.0
# 263                 South Africa          ZAF   17099836.0   17524533.0
# 264                       Zambia          ZMB    3070780.0    3164330.0
# 265                     Zimbabwe          ZWE    3776679.0    3905038.0
#
#             1962         1963         1964         1965         1966  \
# ...

# %%
 # df.to_excel("World_Poulation.xlsx", index=False)

# %%
df1 = df.drop(['1960','1961','1962','1963','1964','1965','1966','1967','1968','1969','1970','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980'],axis=1)
df1
# Out:
#                     Country Name Country Code         1981         1982  \
# 0                          Aruba          ABW      60561.0      61341.0
# 1    Africa Eastern and Southern          AFE  234058404.0  240999134.0
# 2                    Afghanistan          AFG   13171679.0   12882518.0
# 3     Africa Western and Central          AFW  160223588.0  164689764.0
# 4                         Angola          AGO    8640478.0    8952971.0
# ..                           ...          ...          ...          ...
# 261                       Kosovo          XKX    1552000.0    1582000.0
# 262                  Yemen, Rep.          YEM    8231905.0    8541605.0
# 263                 South Africa          ZAF   29333095.0   30150448.0
# 264                       Zambia          ZMB    6055361.0    6265869.0
# 265                     Zimbabwe          ZWE    7675582.0    7958239.0
#
#             1983         1984         1985         1986         1987  \
# ...

# %%
df2 = df1.drop(['1981','1982','1983','1984','1985','1986','1987','1988','1989','1990','1991','1992','1993','1994','1995','1996','1997','1998','1999'],axis=1)
df2
# Out:
#                     Country Name Country Code         2000         2001  \
# 0                          Aruba          ABW      90866.0      92892.0
# 1    Africa Eastern and Southern          AFE  398113044.0  408522129.0
# 2                    Afghanistan          AFG   20779957.0   21606992.0
# 3     Africa Western and Central          AFW  267214544.0  274433894.0
# 4                         Angola          AGO   16395477.0   16945753.0
# ..                           ...          ...          ...          ...
# 261                       Kosovo          XKX    1700000.0    1701154.0
# 262                  Yemen, Rep.          YEM   17409071.0   17918369.0
# 263                 South Africa          ZAF   44967713.0   45571272.0
# 264                       Zambia          ZMB   10415942.0   10692197.0
# 265                     Zimbabwe          ZWE   11881482.0   11923906.0
#
#             2002         2003         2004         2005         2006  \
# ...

# %%
df2.to_excel("World_Poulation_by_countries.xlsx", index=False)

# %%
df2.describe()
# Out:
#                2000          2001          2002          2003          2004  \
# count  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   2.443804e+08  2.477621e+08  2.511427e+08  2.545388e+08  2.579580e+08
# std    7.753492e+08  7.856437e+08  7.958574e+08  8.060498e+08  8.162574e+08
# min    9.392000e+03  9.478000e+03  9.593000e+03  9.724000e+03  9.871000e+03
# 25%    1.228359e+06  1.258008e+06  1.277210e+06  1.283564e+06  1.313492e+06
# 50%    8.170172e+06  8.231150e+06  8.427061e+06  8.557160e+06  8.680516e+06
# 75%    4.917650e+07  4.866240e+07  4.987167e+07  5.142558e+07  5.306887e+07
# max    6.114324e+09  6.193664e+09  6.272724e+09  6.351856e+09  6.431527e+09
#
#                2005          2006          2007          2008          2009  \
# count  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   2.614031e+08  2.648752e+08  2.683706e+08  2.719208e+08  2.754863e+08
# ...
